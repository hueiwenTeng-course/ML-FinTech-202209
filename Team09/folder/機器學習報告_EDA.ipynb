# %% [markdown]
# 1. Show the summary statistics of all numerical variables.

# %% [markdown]
# 將會使用的套件載入

# %%
import pandas as pd 
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt
import time
import math   # This will import math module

# %%
pd.options.display.max_columns = None

# %%
dataset_return=pd.read_csv('data(return).csv')
dataset_return
# Out:
#            date  2308 (up or down)  2308 vloume (thousand)  2360 (return)  \
# 0     2011/7/19                  1                  331924      -0.005256
# 1     2011/7/20                  1                  300740      -0.042272
# 2     2011/7/21                  1                  490457      -0.009655
# 3     2011/7/22                  0                  523839       0.036212
# 4     2011/7/25                  0                  575569       0.025537
# ...         ...                ...                     ...            ...
# 2260  2020/9/23                  0                  736007      -0.033742
# 2261  2020/9/24                  0                 1008197      -0.015873
# 2262  2020/9/25                  1                 1574599      -0.019355
# 2263  2020/9/28                  1                 1573496      -0.006579
# 2264  2020/9/29                  1                 1049264       0.006623
#
#       3665 (return)  1536 (return)  1503 (return)  4721 (return)  \
# 0         -0.053205      -0.003659       0.008464      -0.010420
# 1         -0.023053       0.007346       0.005595       0.035092
# 2          0.013270      -0.007292       0.000000      -0.008476
# 3         -0.020378      -0.007356       0.005560       0.001706
# 4          0.034176       0.022221       0.006917       0.003412
# ...             ...            ...            ...            ...
# 2260      -0.007968      -0.004951      -0.031312      -0.024926
# 2261      -0.016065      -0.013931      -0.021212      -0.022557
# 2262      -0.055102      -0.059535      -0.022704      -0.043077
# 2263      -0.025918      -0.037554      -0.010558      -0.049838
# 2264      -0.026608       0.014492       0.020277       0.025380
#
#       2371 (return)  1537 (return)  1723 (return)  6509 (return)  \
# 0          0.007634       0.001955       0.026784       0.040461
# 1          0.030303      -0.005861       0.009317      -0.019444
# 2         -0.003676       0.007859       0.000000       0.016993
# 3          0.018450      -0.005846      -0.006154       0.000000
# 4         -0.007246       0.017645       0.034055       0.008358
# ...             ...            ...            ...            ...
# 2260      -0.016077      -0.003572      -0.004287      -0.044572
# 2261       0.003268      -0.007168      -0.009689      -0.042599
# 2262      -0.013029      -0.007221      -0.016304      -0.050845
# 2263       0.003300      -0.007272       0.001104      -0.004464
# 2264       0.019737       0.003663       0.005519       0.006726
#
#       8183 (return)  1533 (return)  taiwan_index (return)  SP500 (return)  \
# 0          0.000000      -0.004809              -0.001640        0.016309
# 1         -0.003878      -0.027372               0.021303       -0.000671
# 2         -0.001287       0.001653               0.001260        0.013546
# 3         -0.022086       0.029754               0.005527        0.000908
# 4          0.006639      -0.017659              -0.009333       -0.005643
# ...             ...            ...                    ...             ...
# 2260      -0.020359       0.000000              -0.004874       -0.009363
# 2261      -0.010388      -0.020134              -0.025390        0.013406
# 2262      -0.028873      -0.015410              -0.002566        0.009082
# 2263      -0.037838      -0.006959               0.018789       -0.003406
# 2264       0.028092       0.005255               0.000399        0.002849
#
#       2308 foreign investment (m)  2308 investment credit (m)  \
# 0                           11.54                       21.32
# 1                         -172.41                        5.43
# 2                         -111.50                        5.02
# 3                          -27.07                       61.85
# 4                            7.67                       24.64
# ...                           ...                         ...
# 2260                       -75.31                       -3.85
# 2261                       311.73                      -98.58
# 2262                       115.66                      -50.14
# 2263                       102.90                       12.71
# 2264                       431.98                      -56.76
#
#       2308 dealer (m)        MA20        MA60      MACD        RSI      slowk  \
# 0              -11.44   69.160590   74.930837 -1.332766  44.166169  34.477055
# 1              -16.20   69.127465   74.621618 -1.336238  41.206987  54.798299
# 2                6.79   69.309690   74.334487 -1.218008  46.366737  66.305938
# 3               40.02   69.624440   74.063922 -0.979355  52.033124  88.528439
# 4               57.71   69.806665   73.793355 -0.649065  56.933431  90.952030
# ...               ...         ...         ...       ...        ...        ...
# 2260           -42.11  180.747425  182.586002 -0.901260  42.251281  22.592619
# 2261          -140.60  180.243820  182.865785 -1.130129  41.502154  16.111124
# 2262          -161.96  179.404470  182.977697 -1.449606  38.557135  14.930631
# 2263          -247.28  179.092715  183.073623 -2.180784  30.886104  24.851273
# 2264           -62.96  178.828920  183.233498 -2.269656  42.298153  41.517795
#
#           slowd
# 0     25.163434
# 1     38.200764
# 2     51.860431
# 3     69.877559
# 4     81.928802
# ...         ...
# 2260  42.853993
# 2261  26.358002
# 2262  17.878125
# 2263  18.631009
# 2264  27.099899
#
# [2265 rows x 25 columns]

# %%
dataset_stockprice=pd.read_csv('data(price).csv')
dataset_stockprice
# Out:
#            date  2308 (up or down)  2308 vloume (thousand)  2360 (price)  \
# 0     2011/7/18                  0                  505794         54.03
# 1     2011/7/19                  1                  331924         53.75
# 2     2011/7/20                  1                  300740         51.48
# 3     2011/7/21                  1                  490457         50.98
# 4     2011/7/22                  0                  523839         52.83
# ...         ...                ...                     ...           ...
# 2261  2020/9/23                  0                  736007        147.15
# 2262  2020/9/24                  0                 1008197        144.81
# 2263  2020/9/25                  1                 1574599        142.01
# 2264  2020/9/28                  1                 1573496        141.08
# 2265  2020/9/29                  1                 1049264        142.01
#
#       3665 (price)  1536 (price)  1503 (price)  4721 (price)  2371 (price)  \
# 0            20.35          9.89         24.60         16.97         13.10
# 1            19.27          9.86         24.81         16.79         13.20
# 2            18.82          9.93         24.95         17.38         13.60
# 3            19.07          9.86         24.95         17.23         13.55
# 4            18.69          9.78         25.08         17.26         13.80
# ...            ...           ...           ...           ...           ...
# 2261        234.41         95.47         46.62         63.37         15.30
# 2262        230.65         94.14         45.63         61.94         15.35
# 2263        217.94         88.54         44.59         59.27         15.15
# 2264        212.29         85.21         44.12         56.32         15.20
# 2265        206.64         86.45         45.01         57.75         15.50
#
#       1537 (price)  1723 (price)  6509 (price)  8183 (price)  1533 (price)  \
# 0            24.96         97.19         12.68          6.47         26.24
# 1            25.01         99.79         13.20          6.47         26.12
# 2            24.86        100.72         12.94          6.45         25.40
# 3            25.06        100.72         13.16          6.44         25.45
# 4            24.91        100.10         13.16          6.30         26.20
# ...            ...           ...           ...           ...           ...
# 2261        124.02         87.37         23.52         18.52         29.66
# 2262        123.13         86.52         22.52         18.33         29.06
# 2263        122.25         85.11         21.37         17.80         28.61
# 2264        121.36         85.21         21.28         17.13         28.41
# 2265        121.80         85.68         21.42         17.61         28.56
#
#       taiwan_index (price)  SP500 (price)  2308 foreign investment (m)  \
# 0                  8538.57        1305.44                      -263.49
# 1                  8524.57        1326.73                        11.54
# 2                  8706.17        1325.84                      -172.41
# 3                  8717.14        1343.80                      -111.50
# 4                  8765.32        1345.02                       -27.07
# ...                    ...            ...                          ...
# 2261              12583.88        3155.22                       -75.31
# 2262              12264.38        3197.52                       311.73
# 2263              12232.91        3226.56                       115.66
# 2264              12462.76        3215.57                       102.90
# 2265              12467.73        3224.73                       431.98
#
#       2308 investment credit (m)  2308 dealer (m)    MA20    MA60  MACD  \
# 0                          16.44            46.28   69.36   75.26 -1.41
# 1                          21.32           -11.44   69.16   74.93 -1.33
# 2                           5.43           -16.20   69.13   74.62 -1.34
# 3                           5.02             6.79   69.31   74.33 -1.22
# 4                          61.85            40.02   69.62   74.06 -0.98
# ...                          ...              ...     ...     ...   ...
# 2261                       -3.85           -42.11  180.75  182.59 -0.90
# 2262                      -98.58          -140.60  180.24  182.87 -1.13
# 2263                      -50.14          -161.96  179.40  182.98 -1.45
# 2264                       12.71          -247.28  179.09  183.07 -2.18
# 2265                      -56.76           -62.96  178.83  183.23 -2.27
#
#         RSI  slowk  slowd
# 0     37.19  25.33  20.62
# 1     44.17  34.48  25.16
# 2     41.21  54.80  38.20
# 3     46.37  66.31  51.86
# 4     52.03  88.53  69.88
# ...     ...    ...    ...
# 2261  42.25  22.59  42.85
# 2262  41.50  16.11  26.36
# 2263  38.56  14.93  17.88
# 2264  30.89  24.85  18.63
# 2265  42.30  41.52  27.10
#
# [2266 rows x 25 columns]

# %%
ser1=pd.Series(dataset_stockprice['TWII adjclose'])
ser1
ser2=pd.Series(dataset_stockprice['S&P500 adjclose'])
ser2
# Out:
# 0       1,305.44
# 1       1,326.73
# 2       1,325.84
# 3       1,343.80
# 4       1,345.02
#           ...
# 2262    3,197.52
# 2263    3,226.56
# 2264    3,215.57
# 2265    3,224.73
# 2266    3,251.84
# Name: S&P500 adjclose, Length: 2267, dtype: object

# %%
ser1.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-48cd8e8bee03> in <module>
# ----> 1 ser1.astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1095     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#    1096         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1097         return arr.astype(dtype, copy=True)
#    1098
#    1099     return arr.view(dtype)
#
# ValueError: could not convert string to float: '8,538.57'

# %%
pd.to_numeric(ser1)
pd.to_numeric(ser2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "8,538.57"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-cee3374a5034> in <module>
# ----> 1 pd.to_numeric(ser1)
#       2 pd.to_numeric(ser2)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "8,538.57" at position 0

# %%
coll = [0,23,24]
dataset_stockprice = dataset_stockprice.drop(dataset_stockprice.columns[coll], axis = 1) 
dataset_stockprice
# Out:
#       2308 adjclose  2308 vloume (thousand)  2360 adjclose  3665 adjclose  \
# 0             68.91                  505794          54.03          20.35
# 1             67.92                  331924          53.75          19.27
# 2             69.24                  300740          51.48          18.82
# 3             70.90                  490457          50.98          19.07
# 4             72.56                  523839          52.83          18.69
# ...             ...                     ...            ...            ...
# 2262         175.54                 1008197         144.81         230.65
# 2263         169.31                 1574599         142.01         217.94
# 2264         175.06                 1573496         141.08         212.29
# 2265         177.46                 1049264         142.01         206.64
# 2266         181.30                 1113287         141.54         209.46
#
#       1536 adjclose  1503 adjclose  4721 adjclose  2371 adjclose  \
# 0              9.89          24.60          16.97          13.10
# 1              9.86          24.81          16.79          13.20
# 2              9.93          24.95          17.38          13.60
# 3              9.86          24.95          17.23          13.55
# 4              9.78          25.08          17.26          13.80
# ...             ...            ...            ...            ...
# 2262          94.14          45.63          61.94          15.35
# 2263          88.54          44.59          59.27          15.15
# 2264          85.21          44.12          56.32          15.20
# 2265          86.45          45.01          57.75          15.50
# 2266          88.92          44.64          57.27          17.05
#
#       1537 adjclose  1723 adjclose  6509 adjclose  8183 adjclose  \
# 0             24.96          97.19          12.68           6.47
# 1             25.01          99.79          13.20           6.47
# 2             24.86         100.72          12.94           6.45
# 3             25.06         100.72          13.16           6.44
# 4             24.91         100.10          13.16           6.30
# ...             ...            ...            ...            ...
# 2262         123.13          86.52          22.52          18.33
# 2263         122.25          85.11          21.37          17.80
# 2264         121.36          85.21          21.28          17.13
# 2265         121.80          85.68          21.42          17.61
# 2266         121.80          86.34          21.23          17.22
#
#       1533 adjclose  2308 foreign investment (m)  2308 investment credit (m)  \
# 0             26.24                      -263.49                       16.44
# 1             26.12                        11.54                       21.32
# 2             25.40                      -172.41                        5.43
# 3             25.45                      -111.50                        5.02
# 4             26.20                       -27.07                       61.85
# ...             ...                          ...                         ...
# 2262          29.06                       311.73                      -98.58
# 2263          28.61                       115.66                      -50.14
# 2264          28.41                       102.90                       12.71
# 2265          28.56                       431.98                      -56.76
# 2266          28.71                       126.54                        0.00
#
#       2308 dealer (m)    MA20    MA60  MACD    RSI  slowk  slowd
# 0               46.28   69.36   75.26 -1.41  37.19  25.33  20.62
# 1              -11.44   69.16   74.93 -1.33  44.17  34.48  25.16
# 2              -16.20   69.13   74.62 -1.34  41.21  54.80  38.20
# 3                6.79   69.31   74.33 -1.22  46.37  66.31  51.86
# 4               40.02   69.62   74.06 -0.98  52.03  88.53  69.88
# ...               ...     ...     ...   ...    ...    ...    ...
# 2262          -140.60  180.24  182.87 -1.13  41.50  16.11  26.36
# 2263          -161.96  179.40  182.98 -1.45  38.56  14.93  17.88
# 2264          -247.28  179.09  183.07 -2.18  30.89  24.85  18.63
# 2265           -62.96  178.83  183.23 -2.27  42.30  41.52  27.10
# 2266            23.13  178.80  183.39 -2.12  46.28  72.58  46.31
#
# [2267 rows x 22 columns]

# %%
ser1=pd.DataFrame(ser1)
ser2=pd.DataFrame(ser2)

# %%
dataset_stockprice=pd.concat([dataset_stockprice,ser1,ser2],axis=1)
dataset_stockprice
# Out:
#       2308 adjclose  2308 vloume (thousand)  2360 adjclose  3665 adjclose  \
# 0             68.91                  505794          54.03          20.35
# 1             67.92                  331924          53.75          19.27
# 2             69.24                  300740          51.48          18.82
# 3             70.90                  490457          50.98          19.07
# 4             72.56                  523839          52.83          18.69
# ...             ...                     ...            ...            ...
# 2262         175.54                 1008197         144.81         230.65
# 2263         169.31                 1574599         142.01         217.94
# 2264         175.06                 1573496         141.08         212.29
# 2265         177.46                 1049264         142.01         206.64
# 2266         181.30                 1113287         141.54         209.46
#
#       1536 adjclose  1503 adjclose  4721 adjclose  2371 adjclose  \
# 0              9.89          24.60          16.97          13.10
# 1              9.86          24.81          16.79          13.20
# 2              9.93          24.95          17.38          13.60
# 3              9.86          24.95          17.23          13.55
# 4              9.78          25.08          17.26          13.80
# ...             ...            ...            ...            ...
# 2262          94.14          45.63          61.94          15.35
# 2263          88.54          44.59          59.27          15.15
# 2264          85.21          44.12          56.32          15.20
# 2265          86.45          45.01          57.75          15.50
# 2266          88.92          44.64          57.27          17.05
#
#       1537 adjclose  1723 adjclose  6509 adjclose  8183 adjclose  \
# 0             24.96          97.19          12.68           6.47
# 1             25.01          99.79          13.20           6.47
# 2             24.86         100.72          12.94           6.45
# 3             25.06         100.72          13.16           6.44
# 4             24.91         100.10          13.16           6.30
# ...             ...            ...            ...            ...
# 2262         123.13          86.52          22.52          18.33
# 2263         122.25          85.11          21.37          17.80
# 2264         121.36          85.21          21.28          17.13
# 2265         121.80          85.68          21.42          17.61
# 2266         121.80          86.34          21.23          17.22
#
#       1533 adjclose  2308 foreign investment (m)  2308 investment credit (m)  \
# 0             26.24                      -263.49                       16.44
# 1             26.12                        11.54                       21.32
# 2             25.40                      -172.41                        5.43
# 3             25.45                      -111.50                        5.02
# 4             26.20                       -27.07                       61.85
# ...             ...                          ...                         ...
# 2262          29.06                       311.73                      -98.58
# 2263          28.61                       115.66                      -50.14
# 2264          28.41                       102.90                       12.71
# 2265          28.56                       431.98                      -56.76
# 2266          28.71                       126.54                        0.00
#
#       2308 dealer (m)    MA20    MA60  MACD    RSI  slowk  slowd  \
# 0               46.28   69.36   75.26 -1.41  37.19  25.33  20.62
# 1              -11.44   69.16   74.93 -1.33  44.17  34.48  25.16
# 2              -16.20   69.13   74.62 -1.34  41.21  54.80  38.20
# 3                6.79   69.31   74.33 -1.22  46.37  66.31  51.86
# 4               40.02   69.62   74.06 -0.98  52.03  88.53  69.88
# ...               ...     ...     ...   ...    ...    ...    ...
# 2262          -140.60  180.24  182.87 -1.13  41.50  16.11  26.36
# 2263          -161.96  179.40  182.98 -1.45  38.56  14.93  17.88
# 2264          -247.28  179.09  183.07 -2.18  30.89  24.85  18.63
# 2265           -62.96  178.83  183.23 -2.27  42.30  41.52  27.10
# 2266            23.13  178.80  183.39 -2.12  46.28  72.58  46.31
#
#      TWII adjclose S&P500 adjclose
# 0         8,538.57        1,305.44
# 1         8,524.57        1,326.73
# 2         8,706.17        1,325.84
# 3         8,717.14        1,343.80
# 4         8,765.32        1,345.02
# ...            ...             ...
# 2262     12,264.38        3,197.52
# 2263     12,232.91        3,226.56
# 2264     12,462.76        3,215.57
# 2265     12,467.73        3,224.73
# 2266     12,515.61        3,251.84
#
# [2267 rows x 24 columns]

# %%
dataset_return.head()
# Out:
#         date  2308 adjclose  2308 vloume (thousand)  2360 adjclose  \
# 0  2011/7/19        67.9182                  331924      -0.005256
# 1  2011/7/20        69.2435                  300740      -0.042272
# 2  2011/7/21        70.9000                  490457      -0.009655
# 3  2011/7/22        72.5566                  523839       0.036212
# 4  2011/7/25        71.5626                  575569       0.025537
#
#    3665 adjclose  1536 adjclose  1503 adjclose  4721 adjclose  2371 adjclose  \
# 0      -0.053205      -0.003659       0.008464      -0.010420       0.007634
# 1      -0.023053       0.007346       0.005595       0.035092       0.030303
# 2       0.013270      -0.007292       0.000000      -0.008476      -0.003676
# 3      -0.020378      -0.007356       0.005560       0.001706       0.018450
# 4       0.034176       0.022221       0.006917       0.003412      -0.007246
#
#    1537 adjclose  1723 adjclose  6509 adjclose  8183 adjclose  1533 adjclose  \
# 0       0.001955       0.026784       0.040461       0.000000      -0.004809
# 1      -0.005861       0.009317      -0.019444      -0.003878      -0.027372
# 2       0.007859       0.000000       0.016993      -0.001287       0.001653
# 3      -0.005846      -0.006154       0.000000      -0.022086       0.029754
# 4       0.017645       0.034055       0.008358       0.006639      -0.017659
#
#    2308 foreign investment (m) adjclose  2308 investment credit (m)  \
# 0                                 11.54                       21.32
# 1                               -172.41                        5.43
# 2                               -111.50                        5.02
# 3                                -27.07                       61.85
# 4                                  7.67                       24.64
#
#    2308 dealer (m)       MA20       MA60      MACD        RSI      slowk  \
# 0           -11.44  69.160590  74.930837 -1.332766  44.166169  34.477055
# 1           -16.20  69.127465  74.621618 -1.336238  41.206987  54.798299
# 2             6.79  69.309690  74.334487 -1.218008  46.366737  66.305938
# 3            40.02  69.624440  74.063922 -0.979355  52.033124  88.528439
# 4            57.71  69.806665  73.793355 -0.649065  56.933431  90.952030
#
#        slowd  TWII adjclose  S&P500 adjclose
# 0  25.163434      -0.001640         0.016309
# 1  38.200764       0.021303        -0.000671
# 2  51.860431       0.001260         0.013546
# 3  69.877559       0.005527         0.000908
# 4  81.928802      -0.009333        -0.005643

# %%
dataset_stockprice.head()
# Out:
#         date  2308 adjclose  2308 vloume (thousand)  2360 adjclose  \
# 0  2011/7/18          68.91                  505794          54.03
# 1  2011/7/19          67.92                  331924          53.75
# 2  2011/7/20          69.24                  300740          51.48
# 3  2011/7/21          70.90                  490457          50.98
# 4  2011/7/22          72.56                  523839          52.83
#
#    3665 adjclose  1536 adjclose  1503 adjclose  4721 adjclose  2371 adjclose  \
# 0          20.35           9.89          24.60          16.97          13.10
# 1          19.27           9.86          24.81          16.79          13.20
# 2          18.82           9.93          24.95          17.38          13.60
# 3          19.07           9.86          24.95          17.23          13.55
# 4          18.69           9.78          25.08          17.26          13.80
#
#    1537 adjclose  1723 adjclose  6509 adjclose  8183 adjclose  1533 adjclose  \
# 0          24.96          97.19          12.68           6.47          26.24
# 1          25.01          99.79          13.20           6.47          26.12
# 2          24.86         100.72          12.94           6.45          25.40
# 3          25.06         100.72          13.16           6.44          25.45
# 4          24.91         100.10          13.16           6.30          26.20
#
#    2308 foreign investment (m)  2308 investment credit (m)  2308 dealer (m)  \
# 0                      -263.49                       16.44            46.28
# 1                        11.54                       21.32           -11.44
# 2                      -172.41                        5.43           -16.20
# 3                      -111.50                        5.02             6.79
# 4                       -27.07                       61.85            40.02
#
#     MA20   MA60  MACD    RSI  slowk  slowd TWII adjclose S&P500 adjclose
# 0  69.36  75.26 -1.41  37.19  25.33  20.62      8,538.57        1,305.44
# 1  69.16  74.93 -1.33  44.17  34.48  25.16      8,524.57        1,326.73
# 2  69.13  74.62 -1.34  41.21  54.80  38.20      8,706.17        1,325.84
# 3  69.31  74.33 -1.22  46.37  66.31  51.86      8,717.14        1,343.80
# 4  69.62  74.06 -0.98  52.03  88.53  69.88      8,765.32        1,345.02

# %%
coll = 0
dataset_stockprice = dataset_stockprice.drop(dataset_stockprice.columns[coll], axis = 1) 
dataset_return = dataset_return.drop(dataset_return.columns[coll], axis = 1)

# %%
pd.isnull(dataset_stockprice).values.any()
# Out:
# False

# %%
pd.isnull(dataset_return).values.any()
# Out:
# False

# %%
print(dataset_stockprice.shape)
# Out:
# (2267, 24)

# %%
print(dataset_return.shape)
# Out:
# (2266, 24)

# %% [markdown]
# Data descriptions

# %% [markdown]
# 在這些型別中，整數與浮點數欄位都可以進行所有數值的計算，像是當我們使用 df.describe() 方法時，
# 這兩種數值欄位會自動計算平均數、最大值、最小值、標準差……等統計數值；但字串欄位因為沒有數值意義，
# 無法進行運算，所以只會回傳出現最多次的字串、出現次數以及欄位中有幾種不同的值，
# 跟浮點數與整數型別不同，object 型別欄位利用 describe() 的回傳結果
# 只會有「資料數」、「獨立值數量」、「出現次數最高的值」、「出現率最高的值的出現次數」

# %%
dataset_return.describe(include = 'all')
# Out:
#               date  2308 (up or down)  2308 vloume (thousand)  2360 (return)  \
# count         2265        2265.000000            2.265000e+03    2265.000000
# unique        2265                NaN                     NaN            NaN
# top     2011/12/29                NaN                     NaN            NaN
# freq             1                NaN                     NaN            NaN
# mean           NaN           0.447682            8.507052e+05       0.000704
# std            NaN           0.497365            5.199510e+05       0.023620
# min            NaN           0.000000            1.853800e+04      -0.097656
# 25%            NaN           0.000000            5.057380e+05      -0.012245
# 50%            NaN           0.000000            7.232180e+05       0.000000
# 75%            NaN           1.000000            1.055121e+06       0.011765
# max            NaN           1.000000            5.244223e+06       0.099567
#
#         3665 (return)  1536 (return)  1503 (return)  4721 (return)  \
# count     2265.000000    2265.000000    2265.000000    2265.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.001419       0.001219       0.000310       0.000896
# std          0.028141       0.022919       0.009305       0.026773
# min         -0.100000      -0.100000      -0.081263      -0.100001
# 25%         -0.013672      -0.011450      -0.002816      -0.011390
# 50%          0.000000       0.000000       0.000000       0.000000
# 75%          0.015501       0.012419       0.003636       0.010059
# max          0.100000       0.100001       0.099568       0.100000
#
#         2371 (return)  1537 (return)  1723 (return)  6509 (return)  \
# count     2265.000000    2265.000000    2265.000000    2265.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.000400       0.000817       0.000034       0.000461
# std          0.025567       0.015321       0.013442       0.021501
# min         -0.100000      -0.099173      -0.083599      -0.100004
# 25%         -0.010163      -0.006645      -0.006993      -0.009783
# 50%          0.000000       0.000000       0.000000       0.000000
# 75%          0.009569       0.006969       0.006666       0.008312
# max          0.100000       0.082987       0.099526       0.099796
#
#         8183 (return)  1533 (return)  taiwan_index (return)  SP500 (return)  \
# count     2265.000000    2265.000000            2265.000000     2265.000000
# unique            NaN            NaN                    NaN             NaN
# top               NaN            NaN                    NaN             NaN
# freq              NaN            NaN                    NaN             NaN
# mean         0.000746       0.000300               0.000213        0.000462
# std          0.024752       0.023030               0.009561        0.011158
# min         -0.099030      -0.099999              -0.063125       -0.119841
# 25%         -0.010307      -0.010152              -0.004302       -0.003305
# 50%          0.000000       0.000000               0.000657        0.000582
# 75%          0.009123       0.007937               0.005405        0.005128
# max          0.099996       0.099999               0.063671        0.093828
#
#         2308 foreign investment (m)  2308 investment credit (m)  \
# count                   2265.000000                 2265.000000
# unique                          NaN                         NaN
# top                             NaN                         NaN
# freq                            NaN                         NaN
# mean                       4.405285                   -0.209205
# std                      288.261781                   41.004149
# min                    -2106.100000                 -482.980000
# 25%                     -138.970000                   -9.800000
# 50%                       -0.450000                    0.000000
# 75%                      133.200000                    8.510000
# max                     1727.830000                  371.260000
#
#         2308 dealer (m)         MA20         MA60         MACD          RSI  \
# count       2265.000000  2265.000000  2265.000000  2265.000000  2265.000000
# unique              NaN          NaN          NaN          NaN          NaN
# top                 NaN          NaN          NaN          NaN          NaN
# freq                NaN          NaN          NaN          NaN          NaN
# mean          -0.433978   117.375014   116.383546     0.339966    51.636837
# std           30.967835    30.624899    29.779554     2.257299    11.774578
# min         -338.170000    45.297435    48.155072    -7.401892    10.699493
# 25%           -9.130000   101.328965   101.571415    -0.979355    43.638775
# 50%           -0.430000   125.376630   125.694712     0.193591    51.490248
# 75%            7.940000   138.868225   138.735715     1.723890    59.439099
# max          251.660000   191.658945   183.233498     9.462843    87.056735
#
#               slowk        slowd
# count   2265.000000  2265.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      51.839729    51.833615
# std       24.995922    22.897045
# min        1.449191     3.915980
# 25%       30.303519    32.803324
# 50%       52.777240    52.591093
# 75%       73.013236    70.977210
# max      100.000000    96.621285

# %%
dataset_stockprice.describe(include = 'all')
# Out:
#               date  2308 (up or down)  2308 vloume (thousand)  2360 (price)  \
# count         2266        2266.000000            2.266000e+03   2266.000000
# unique        2266                NaN                     NaN           NaN
# top     2011/12/29                NaN                     NaN           NaN
# freq             1                NaN                     NaN           NaN
# mean           NaN           0.447485            8.505530e+05     81.189748
# std            NaN           0.497344            5.198867e+05     37.519572
# min            NaN           0.000000            1.853800e+04     36.800000
# 25%            NaN           0.000000            5.057520e+05     49.847500
# 50%            NaN           0.000000            7.232025e+05     64.120000
# 75%            NaN           1.000000            1.054666e+06    120.400000
# max            NaN           1.000000            5.244223e+06    173.640000
#
#         3665 (price)  1536 (price)  1503 (price)  4721 (price)  2371 (price)  \
# count    2266.000000   2266.000000   2266.000000   2266.000000   2266.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean      118.506818     73.466571     31.855613     37.513751     13.281787
# std        68.183576     43.248701      5.827068     26.185755      8.361177
# min        12.520000      7.100000     20.710000     12.540000      4.590000
# 25%        74.360000     34.480000     27.130000     16.310000      7.472500
# 50%       119.630000     88.555000     31.790000     25.285000      9.520000
# 75%       177.590000    111.390000     35.500000     59.902500     18.600000
# max       270.440000    140.840000     48.970000    124.730000     42.400000
#
#         1537 (price)  1723 (price)  6509 (price)  8183 (price)  1533 (price)  \
# count    2266.000000   2266.000000   2266.000000   2266.000000   2266.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       80.454342    101.748407     15.639590     10.760084     33.305525
# std        35.391029     16.048198      3.038157      6.114929     12.260910
# min        18.470000     67.870000      7.920000      3.760000     11.940000
# 25%        46.340000     86.480000     14.620000      5.232500     25.452500
# 50%        88.325000     99.960000     16.140000      7.860000     35.720000
# 75%       110.335000    115.100000     17.210000     16.340000     39.415000
# max       131.030000    137.350000     26.030000     28.120000     70.250000
#
#         taiwan_index (price)  SP500 (price)  2308 foreign investment (m)  \
# count            2266.000000    2266.000000                  2266.000000
# unique                   NaN            NaN                          NaN
# top                      NaN            NaN                          NaN
# freq                     NaN            NaN                          NaN
# mean             9326.817485    2156.138447                     4.287061
# std              1391.086695     563.367678                   288.253083
# min              6633.330000    1099.230000                 -2106.100000
# 25%              8191.280000    1727.427500                  -139.090000
# 50%              9206.690000    2089.435000                    -0.705000
# 75%             10517.982500    2663.912500                   133.070000
# max             12976.760000    3386.150000                  1727.830000
#
#         2308 investment credit (m)  2308 dealer (m)         MA20         MA60  \
# count                  2266.000000      2266.000000  2266.000000  2266.000000
# unique                         NaN              NaN          NaN          NaN
# top                            NaN              NaN          NaN          NaN
# freq                           NaN              NaN          NaN          NaN
# mean                     -0.201858        -0.413363   117.353866   116.365428
# std                      40.996588        30.976546    30.634601    29.785425
# min                    -482.980000      -338.170000    45.300000    48.160000
# 25%                      -9.800000        -9.120000   101.322500   101.540000
# 50%                       0.000000        -0.430000   125.365000   125.670000
# 75%                       8.525000         7.955000   138.870000   138.737500
# max                     371.260000       251.660000   191.660000   183.230000
#
#                MACD          RSI        slowk        slowd
# count   2266.000000  2266.000000  2266.000000  2266.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean       0.339197    51.630556    51.828142    51.819894
# std        2.257104    11.775850    24.996629    22.901273
# min       -7.400000    10.700000     1.450000     3.920000
# 25%       -0.980000    43.632500    30.277500    32.800000
# 50%        0.190000    51.475000    52.740000    52.570000
# 75%        1.720000    59.425000    72.987500    70.972500
# max        9.460000    87.060000   100.000000    96.620000

# %% [markdown]
# 2. Identify categorical and continuous variables.

# %% [markdown]
# 幫助我們理解該變數是 continuous (numerical) 還是 discrete (categorical)

# %% [markdown]
# age,fnlwgt,educational-num,capital-gain,capital-loss,hours-per-week為continuous variables，其他為categorical variables

# %%
print(dataset.dtypes)
# Out:
# 2308 adjclose                  float64
# 2308 vloume (thousand)           int64
# 2308 foreign investment (m)    float64
# 2308 investment credit (m)     float64
# 2308 dealer (m)                float64
# MA20                           float64
# MA60                           float64
# MACD                           float64
# RSI                            float64
# slowk                          float64
# slowd                          float64
# 2360 return                    float64
# 3665 return                    float64
# 1536 return                    float64
# 1503 return                    float64
# 4721 return                    float64
# 2371 return                    float64
# 1537 return                    float64
# 1723 return                    float64
# 6509 return                    float64
# 8183 return                    float64
# 1533 return                    float64
# dtype: object

# %% [markdown]
# 判斷每個變數有幾種不同的值

# %%
print(dataset.nunique())
# Out:
# 2308 adjclose                   875
# 2308 vloume (thousand)         2266
# 2308 foreign investment (m)    2230
# 2308 investment credit (m)     1752
# 2308 dealer (m)                1826
# MA20                           2164
# MA60                           2233
# MACD                           2266
# RSI                            2013
# slowk                          2218
# slowd                          2266
# 2360 return                    2059
# 3665 return                    2053
# 1536 return                    1935
# 1503 return                    1626
# 4721 return                    2040
# 2371 return                    1949
# 1537 return                    1654
# 1723 return                    1522
# 6509 return                    1821
# 8183 return                    1997
# 1533 return                    2012
# dtype: int64

# %% [markdown]
# 4. Draw bar plots for each categorical variable.

# %% [markdown]
# 以下這些圖表現出分配圖，可分成兩個版本，如下

# %%
col_names = ['2308 adjclose', '2308 vloume (thousand)', '2308 foreign investment (m)', '2308 investment credit (m)', '2308 dealer (m)', 'MA20','MA60','MACD','RSI','slowk','slowd','2360 return','3665 return','1536 return',
             '1503 return','4721 return','2371 return','1537 return','1723 return','6509 return','8183 return','1533 return'] 
fig, ax = plt.subplots(len(col_names), figsize=(15,120))
for i, col_val in enumerate(col_names):
    sns.distplot(dataset[col_val], hist = True, ax = ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize = 8)
    ax[i].set_ylabel('Count', fontsize = 8)

plt.savefig("機器學習報告distCon.png") # plt.savefig() needs to be in front of plt.show()
plt.show()
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\kevin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dataset_stockprice.corr(), annot = True, fmt='.2f',center=0.0, cmap='Spectral_r'); # cmap="YlGnBu",
plt.savefig("機器學習報告heatmap_dataset_stockprice.png")
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dataset_return.corr(), annot = True, fmt='.2f',center=0.0, cmap='Spectral_r'); # cmap="YlGnBu",
plt.savefig("機器學習報告heatmap_dataset_return.png")
plt.show()

# %%
dataset_return_new=pd.read_excel('機器學習資料_報酬率的_拿來畫圖的.xlsx')
dataset_return_new
# Out:
#              日期  2308 return  2308 vloume (thousand)  \
# 0     2011/7/20     0.019513                  300740
# 1     2011/7/21     0.023923                  490457
# 2     2011/7/22     0.023365                  523839
# 3     2011/7/25    -0.013700                  575569
# 4     2011/7/26    -0.002919                  615238
# ...         ...          ...                     ...
# 2260  2020/9/24    -0.010811                 1008197
# 2261  2020/9/25    -0.035519                 1574599
# 2262  2020/9/28     0.033995                 1573496
# 2263  2020/9/29     0.013698                 1049264
# 2264  2020/9/30     0.021622                 1113287
#
#       2308 foreign investment (m)  2308 investment credit (m)  \
# 0                         -172.41                        5.43
# 1                         -111.50                        5.02
# 2                          -27.07                       61.85
# 3                            7.67                       24.64
# 4                          -48.28                       22.79
# ...                           ...                         ...
# 2260                       311.73                      -98.58
# 2261                       115.66                      -50.14
# 2262                       102.90                       12.71
# 2263                       431.98                      -56.76
# 2264                       126.54                        0.00
#
#       2308 dealer (m)        MA20        MA60      MACD        RSI  ...  \
# 0              -16.20   69.127465   74.621618 -1.336238  41.206987  ...
# 1                6.79   69.309690   74.334487 -1.218008  46.366737  ...
# 2               40.02   69.624440   74.063922 -0.979355  52.033124  ...
# 3               57.71   69.806665   73.793355 -0.649065  56.933431  ...
# 4               63.72   69.961880   73.569003 -0.462187  53.407777  ...
# ...               ...         ...         ...       ...        ...  ...
# 2260          -140.60  180.243820  182.865785 -1.130129  41.502154  ...
# 2261          -161.96  179.404470  182.977697 -1.449606  38.557135  ...
# 2262          -247.28  179.092715  183.073623 -2.180784  30.886104  ...
# 2263           -62.96  178.828920  183.233498 -2.269656  42.298153  ...
# 2264            23.13  178.804940  183.385380 -2.122118  46.278387  ...
#
#       3665 return  1536 return  1503 return  4721 return  2371 return  \
# 0       -0.023053     0.007346     0.005595     0.035092     0.030303
# 1        0.013270    -0.007292     0.000000    -0.008476    -0.003676
# 2       -0.020378    -0.007356     0.005560     0.001706     0.018450
# 3        0.034176     0.022221     0.006917     0.003412    -0.007246
# 4       -0.031608    -0.028987    -0.012360     0.000000    -0.010949
# ...           ...          ...          ...          ...          ...
# 2260    -0.016065    -0.013931    -0.021212    -0.022557     0.003268
# 2261    -0.055102    -0.059535    -0.022704    -0.043077    -0.013029
# 2262    -0.025918    -0.037554    -0.010558    -0.049838     0.003300
# 2263    -0.026608     0.014492     0.020277     0.025380     0.019737
# 2264     0.013667     0.028572    -0.008368    -0.008250     0.100000
#
#       1537 return  1723 return  6509 return  8183 return  1533 return
# 0       -0.005861     0.009317    -0.019444    -0.003878    -0.027372
# 1        0.007859     0.000000     0.016993    -0.001287     0.001653
# 2       -0.005846    -0.006154     0.000000    -0.022086     0.029754
# 3        0.017645     0.034055     0.008358     0.006639    -0.017659
# 4        0.030833    -0.002994    -0.027626    -0.006595    -0.024511
# ...           ...          ...          ...          ...          ...
# 2260    -0.007168    -0.009689    -0.042599    -0.010388    -0.020134
# 2261    -0.007221    -0.016304    -0.050845    -0.028873    -0.015410
# 2262    -0.007272     0.001104    -0.004464    -0.037838    -0.006959
# 2263     0.003663     0.005519     0.006726     0.028092     0.005255
# 2264     0.000000     0.007683    -0.008908    -0.021855     0.005227
#
# [2265 rows x 23 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dataset_return_new.corr(), annot = True, fmt='.2f',center=0.0, cmap='Spectral_r'); # cmap="YlGnBu",
plt.savefig("機器學習報告heatmap_dataset_return_new.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-aad372c93d2e> in <module>
#       1 plt.figure(figsize=(20,20))
# ----> 2 sns.heatmap(dataset_return_new.corr(), annot = True, fmt='.2f',center=0.0, cmap='Spectral_r'); # cmap="YlGnBu",
#       3 plt.savefig("機器學習報告heatmap_dataset_return_new.png")
#       4 plt.show()
#
# NameError: name 'dataset_return_new' is not defined
